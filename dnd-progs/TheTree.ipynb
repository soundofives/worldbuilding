# %%
from ete3 import Tree, TreeStyle, NodeStyle,faces, TextFace, add_face_to_node

# %%
t = Tree() # Creates an empty tree
#############################
#WAITH TREE
############
#=
culture = "ProtoInivatic"
t.add_child(name=culture)
lang="Proto-Inivatic (Proto - Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#==
culture = "Sarnean"
ProtoInivatic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#==
culture = "Uso"
Sarnean.add_sister(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Akh"
Uso.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Lung"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Luan"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Ceat"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Rhun"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#====
culture = "Anariimaic"
Rhun.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#=====
culture = "Vanhar"
Anariimaic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Erya"
Anariimaic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(ProtoInivatic.get_ascii(show_internal=True))
# Out:
#                     /-Lung
#                    |
#                    |--Luan
#              /Sarnean
#             |      |--Ceat
#             |      |
# -ProtoInivatic     |              /-Vanhar
#             |       \RhunAnariimaic
#             |                     \-Erya
#             |
#              \Uso-Akh

# %%
#############################
#LOSS'KELVAR AND ORUN TREE
############
culture = "ProtoKeleshi"
t.add_child(name=culture)
lang="Proto-Keleshi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Keleshi"
ProtoKeleshi.add_child(name=culture)
lang="Keleshi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoOrun"
ProtoKeleshi.add_child(name=culture)
lang="Proto-Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Akobean"
ProtoOrun.add_child(name=culture)
lang="Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Isikal"
ProtoOrun.add_child(name=culture)
lang="Isikali"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Kekere"
ProtoOrun.add_child(name=culture)
lang="Yaltalese"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Nlashikir"
Akobean.add_child(name=culture)
lang="Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(ProtoKeleshi.get_ascii(show_internal=True))
# Out:
#             /-Keleshi
#            |
# -ProtoKeleshi        /Akobean-Nlashikir
#            |        |
#             \ProtoOrun-Isikal
#                     |
#                      \-Kekere

# %%
#############################
#ASTAR CULTURES
############
culture = "Yfanald"
t.add_child(name=culture)
lang="Anariimaic"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Tellin"
Yfanald.add_child(name=culture)
lang="Wesaxian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Eyasolian"
Tellin.add_child(name=culture)
lang="Wesaxian -> Eyasolian by 34200"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Rajanan"
Tellin.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Thandairian"
Tellin.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Suhairian"
Thandairian.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)


culture = "Akshani"
Thandairian.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoHuroman"
Yfanald.add_child(name=culture)
lang="Proto-Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "CentralHuroman"
ProtoHuroman.add_child(name=culture)
lang="Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "CoastalHuroman"
ProtoHuroman.add_child(name=culture)
lang="Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoEastern"
Yfanald.add_child(name=culture)
lang="ProtoEastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Ghahaka"
ProtoEastern.add_child(name=culture)
lang="Ghahakan"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "NorthSamisian"
ProtoEastern.add_child(name=culture)
lang="dia. Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Sakula"
NorthSamisian.add_child(name=culture)
lang="dia. Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "EastSamisian"
ProtoEastern.add_child(name=culture)
lang="East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Gairiatic"
EastSamisian.add_child(name=culture)
lang="dia. East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Darungian"
EastSamisian.add_child(name=culture)
lang="dia. East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "JirElesin"
EastSamisian.add_child(name=culture)
lang="Jir-Elesi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Vinaltakhan"
ProtoEastern.add_child(name=culture)
lang="Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "JurHudai"
Vinaltakhan.add_child(name=culture)
lang="Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Savatumra"
Vinaltakhan.add_child(name=culture)
lang="Savatumran"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Zarrakayan"
Savatumra.add_child(name=culture)
lang="Zarrakayan"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(Yfanald.get_ascii(show_internal=True))
# Out:
#              /-Eyasolian
#             |
#        /Tellin-Rajanan
#       |     |
#       |     |           /-Suhairian
#       |      \Thandairian
#       |                 \-Akshani
#       |
#       |            /-CentralHuroman
# -YfanaldProtoHuroman
#       |            \-CoastalHuroman
#       |
#       |            /-Ghahaka
#       |           |
#       |           |-NorthSamisian-Sakula
#       |           |
#       |           |            /-Gairiatic
#        \ProtoEastern          |
#                   |-EastSamisian-Darungian
#                   |           |
#                   |            \-JirElesin
#                   |
#                   |           /-JurHudai
#                    \Vinaltakhan
#                               \Savatumra-Zarrakayan

# %%
print(t.get_ascii(show_internal=True))
# Out:
#                        /-Lung
#                       |
#                       |--Luan
#                 /Sarnean
#                |      |--Ceat
#                |      |
#    /ProtoInivatic     |              /-Vanhar
#   |            |       \RhunAnariimaic
#   |            |                     \-Erya
#   |            |
#   |             \Uso-Akh
#   |
#   |            /-Keleshi
#   |           |
#   |-ProtoKeleshi        /Akobean-Nlashikir
#   |           |        |
#   |            \ProtoOrun-Isikal
# --|                    |
#   |                     \-Kekere
#   |
#   |             /-Eyasolian
#   |            |
#   |       /Tellin-Rajanan
#   |      |     |
#   |      |     |           /-Suhairian
#   |      |      \Thandairian
#   |      |                 \-Akshani
#   |      |
#   |      |            /-CentralHuroman
#    \YfanaldProtoHuroman
#          |            \-CoastalHuroman
#          |
#          |            /-Ghahaka
#          |           |
#          |           |-NorthSamisian-Sakula
#          |           |
#          |           |            /-Gairiatic
#           \ProtoEastern          |
#                      |-EastSamisian-Darungian
#                      |           |
#                      |            \-JirElesin
#                      |
#                      |           /-JurHudai
#                       \Vinaltakhan
#                                  \Savatumra-Zarrakayan

# %%
ts = TreeStyle()
ts.show_leaf_name = True
ts.scale =  120 # 120 pixels per branch length unit
t.show(tree_style=ts)

# %%
ts = TreeStyle()
ts.show_leaf_name = True
ts.mode = "c"
ts.arc_start = -90 # 0 degrees = 3 o'clock
ts.arc_span = 180
t.show(tree_style=ts)

# %%
# for n in t.traverse():
#     if n.exist == "extinct"
#     nstyle = NodeStyle()
#     nstyle["fgcolor"] = "red"
#     nstyle["size"] = 15
#     n.set_style(nstyle)

# # Let's now modify the aspect of the root node
# t.img_style["size"] = 30
# t.img_style["fgcolor"] = "blue"

# t.show(tree_style=ts)

# %% [markdown]
# # Languages

# %%
def mylayout(node):
    #Add the general start date to each node
    # text faces support multiline. We add a text face
    # with the whole description of each leaf.
#     descFace = faces.TextFace(node.name, fsize=10)
#     descFace.margin_top = 10
#     descFace.margin_bottom = 10
#     descFace.border.margin = 1
    if not node.is_root():
        F = TextFace(node.name+"\n"+str(node.date), tight_text=False)
        add_face_to_node(F, node, column=0, position="branch-right")

    # Note that this faces is added in "aligned" mode
#     faces.add_face_to_node(descFace, node, column=0, aligned=True)

#     # Sets the style of leaf nodes
#     node.img_style["size"] = 5
#     node.img_style["shape"] = "circle"
# #     #If node is an internal node
#     else:
#         # Sets the style of internal nodes
#         node.img_style["size"] = 6
#         node.img_style["shape"] = "circle"
#         node.img_style["fgcolor"] = "#000000"

# %%
# ts = TreeStyle()
# ts.show_leaf_name = False
# def my_layout(node):
#         F = TextFace(node.name, tight_text=True)
#         add_face_to_node(F, node, column=0, position="branch-right")
# ts.layout_fn = my_layout
# t.show(tree_style=ts)

# %%
l = Tree() # Creates an empty tree
#############################
#WAITH TREE
############
#=
lang = "ProtoInivatic"
l.add_child(name=lang)
date=500000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Inivatic"
ProtoInivatic.add_child(name=lang)
date=350000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoLeilomic"
Inivatic.add_child(name=lang)
date=68000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)


lang = "Yfanald"
ProtoLeilomic.add_child(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Jorosh"
Yfanald.add_sister(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Saxum"
Yfanald.add_sister(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Eldh"
Yfanald.add_sister(name=lang)
date=57600
notes="Proto-Celtic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoAmarthian"
Eldh.add_child(name=lang)
date=47000
notes="Proto-Celtic + Estonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Amarthian"
ProtoAmarthian.add_child(name=lang)
date=37000
notes="Gaulish + Estonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoKeleshi"
l.add_child(name=lang)
date=500000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Keleshi"
ProtoKeleshi.add_child(name=lang)
date=350000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoEbo"
ProtoKeleshi.add_child(name=lang)
date=280000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ebo"
ProtoEbo.add_child(name=lang)
date=164000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Isikali"
ProtoEbo.add_child(name=lang)
date=160000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Yaltalese"
ProtoEbo.add_child(name=lang)
date=160000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Emakeel"
l.add_child(name=lang)
date=350000
notes="Estonian, language of the giants"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

print(l.get_ascii(show_internal=True))
# Out:
#                                      /-Yfanald
#                                     |
#                                     |--Jorosh
#    /ProtoInivaticInivaticProtoLeilomic
#   |                                 |--Saxum
#   |                                 |
#   |                                  \EldhProtoAmarthian-Amarthian
#   |
#   |            /-Keleshi
# --|           |
#   |-ProtoKeleshi       /-Ebo
#   |           |       |
#   |            \ProtoEbo-Isikali
#   |                   |
#   |                    \-Yaltalese
#   |
#    \-Emakeel

# %%
# Saxum -> Wesaxian (Western *-Aryan branch)
#     -Branches into Eyasolian, (Pahari - Insular Indic branch. Mixes with Iranian in south Austera w/ loans from Iranian)
#     Wesaxian -> Later Thandairian (Vedic Sanskrit)
#         Later Thandairian -> Akshani (Vedic Sanskrit + Kati)
#     Wesaxian -> Proto-Eyasolian (Proto-Pahari + Elu Prakrit), lowland and highland dialects
#         Proto-Eyasolian (highland) -> Eyasolic (Sinhalese)
#         Proto-Eyasolian (lowland) -> Lowland remnants (Proto-Dogri + Sinhalese)
#         Proto-Eyasolian (lowland) -> Early East Austeran (Pahari? Proto-Nepali?)

# 49700 - Saxum -> Wesaxian
#     45900 - Wesaxian -> Proto-Eyasolian (Highland and Lowland dialects), Lowland dialect on mainland dies out around 39000
#         31200 - Proto-Eyasolian (Highland dialect) -> Eyasolic
#         33200 - Proto-Eyasolian (Lowland dialect) -> Proto-East Austeran
#             XXXXXXX.........
#         32900 - Proto-Eyasolian (Lowland dialect) -> Lowland remnants
#     41000 - Later Thandairian
#         36200 - Akshani

lang = "Wesaxian"
Saxum.add_child(name=lang)
date=49700
notes="Western *-Aryan branch"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LaterThandairian"
Wesaxian.add_child(name=lang)
date=41000
notes="Vedic Sanskrit"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Akshani"
LaterThandairian.add_child(name=lang)
date=36200
notes="Vedic Sanskrit + Kati"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoEyasolian"
Wesaxian.add_child(name=lang)
date=45900
notes="Highland and Lowland dialects, Proto-Pahari + Elu Prakrit"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Eyasolic"
ProtoEyasolian.add_child(name=lang)
date=31200
notes="Highland dialect -> Sinhalese"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LowlandRemnants"
ProtoEyasolian.add_child(name=lang)
date=32900
notes="Lowland -> Proto-Dogri + Sinhalese"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoEastAusteran"
ProtoEyasolian.add_child(name=lang)
date=33200
notes="Lowland -> Proto-Pahari / Proto-Nepali"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

# Saxum -> ProtoHuroman (Eastern, southern *-Aryan branch), two dialects: coastal and central
#     ProtoHuroman (Central) -> Northern Huroman (Proto-Magadhi)
#         Northern Huroman -> Shukunaic (Proto-Bihari + Gbe)
#         Northern Huroman -> Ashamaic (Assamese + Yoruba)
#     ProtoHuroman (Central) -> Central Huroman (Proto-Magadhi var1)
#         Central Huroman -> Deshgairi (Marathi + Proto-Maharashthri)
#     ProtoHuroman (Coastal) -> Marmanaic (Proto-Maharashthri + Akan)
#         Marmanaic -> Later Marmanaic (Marathi + Akan)
#     ProtoHuroman (Coastal) -> Omanusian (Proto-Maharashthri + Sanskrit + Itsekiri)
# 49000 - Saxum -> ProtoHuroman (has Central and Coastal dialects); Nomadic Huromans population first (53,600) , then large-scale agricultral demic diffusion takes over (52,500). Two distinct populations; Nomadic dialects spread and diversify, but don't mature into distinct languages before demic replacement. Nomadic dialects lead to substratum in eventual coastal languages. (52,000) Huroma isolated. ~40000, influx of Thandairian languages
#     47200 - ProtoHuroman (Central) -> Northern Huroman
#                                     -> Central Huroman
#         36900 - Northern Huroman -> Shukunaic (Northern Huroman + ProtoHuroman Coastal northern dialect)
#         37000 - Northern Huroman -> Ashamaic (Northern Huroman + Yoruba var)
#         35200 - Central Huroman -> Deshgairi (Central Huroman + Thandairian)
#                                 -> Later Central Huroman
#     42000 - ProtoHuroman (Coastal) -> Marman
#         32900 - Marman -> Later Marman (Marman var, + Yoruba)
#     39000 - ProtoHuroman (Coastal) -> Omanusian


lang = "ProtoHuroman"
Saxum.add_child(name=lang)
date=49000
notes="Eastern, souther *-Aryan branch, two dialects: coastal and central"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "NorthernHuroman"
ProtoHuroman.add_child(name=lang)
date=47200
notes="Central dialect -> Proto-Magadhi"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Shukunaic"
NorthernHuroman.add_child(name=lang)
date=36900
notes="Proto-Bihari + Gbe"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ashamaic"
NorthernHuroman.add_child(name=lang)
date=37000
notes="Assamese + Yoruba"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "CentralHuroman"
ProtoHuroman.add_child(name=lang)
date=47200
notes="Central dialect -> Proto-Magadhi var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Deshgairi"
CentralHuroman.add_child(name=lang)
date=35200
notes="Marathi + Proto-Maharashthri"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Marmanaic"
ProtoHuroman.add_child(name=lang)
date=42000
notes="Coastal dialect -> Proto-Maharashthri + Akan"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LaterMarmanaic"
Marmanaic.add_child(name=lang)
date=32900
notes="Maharathi + Akan"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Omanusian"
ProtoHuroman.add_child(name=lang)
date=39000
notes="Coastal dialect -> Proto-Maharashthri + Vedic Sanskrit + Itsekiri"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

# Saxum -> Proto-Eastern (Dardic + *-Iranian branch), includes southern, central, and eastern dialects
#     Proto-Eastern (Central dialect)-> Early Ghahakan (Proto-Dardic; branches for North, Central, East)
#         -Early Ghahakan collapses with the drying of the central river. Northern tribes survive; East fold into JirElesi
#         North Ghahakan -> Uruvandi (Shina)
#         Central Ghahakan -> Shestraluki (Kashmiri)
#     Proto-Eastern (Eastern dialect)-> EasternLowland (Proto-Iranian, leaning western)
#         EasternLowland -> JirElesi (Old Persian + Yoruba)
#             JirElesi -> Post-JirElesi (Old Persian + Yoruba var. + Pashayi)
#         EasternLowland -> Darungiatic (Median / Proto-Kurdish + Yoruba), matures in the Tiyaran phase
#             Darungiatic -> Dewari (Median + Yoruba var.)
#                         -> SouthernDarungiatic (Zaza-Gorani + Yoruba)
#                         -> Shathradaic (Parthian + Yoruba)
#     Proto-Eastern (Eastern dialect)-> Gairian (Proto-Caspian / Proto-Gilaki)
#         Gairian -> Later Gairian (Gilaki)
#     Proto-Eastern (Southern dialect) -> Zarrakayan (Proto-Iranian, leaning eastern + Vedic Sanskrit)
#         Zarrakayan -> Hemanaic (Proto Southeastern Iranian, Proto-Pashto, + Gandhari)
#                     -> Janangh (Pamiri + Shauraseni),
#                     -> SouthernFarmers (Proto-Pashto + Niya),
#                     -> Shanurvic (Pamiri + Paisaci)
#     Proto-Eastern (Southern dialect) -> JurHudai (Proto-Northeastern Iranian, Proto-Bactrian)
# 49700 - Saxum -> ProtoEastern
#     48300 - Eastern Lowland
#         41500 - JirElesi
#             33800 - Post-JirElesi
#         41300 - Darungiatic
#             32000 - Darungiatic -> Dewari, Southern Darungiatic, Shathradaic
#     48300 - Gairian
#         32100 - Later Gairian
#     47500 - North, Central, East Ghahakan
#         39200 - North Ghahakan -> Uruvandi
#         37200 - Central Ghahakan -> Shestraluki
#     39000 - ProtoEastern -> Zarrakayan
#         34500 - Zarrakayan -> RGC/Hemanaic, Janangh, SouthernFarmers, Shanurvaic
#     38800 - ProtoEastern -> JurHudai


lang = "ProtoEastern"
Saxum.add_child(name=lang)
date=49700
notes="Dardic + *-Iranian branch, includes southern, central, and eastern dialects"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "EarlyNorthGhahakan"
ProtoEastern.add_child(name=lang)
date=47500
notes="Central dialect -> Proto-Dardic var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Uruvandi"
EarlyNorthGhahakan.add_child(name=lang)
date=39200
notes="Shina"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "EarlyEastGhahakan"
ProtoEastern.add_child(name=lang)
date=47500
notes="Central dialect -> Proto-Dardic var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "EarlyCentralGhahakan"
ProtoEastern.add_child(name=lang)
date=47500
notes="Central dialect -> Proto-Dardic var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Shestraluki"
EarlyCentralGhahakan.add_child(name=lang)
date=37200
notes="Kashmiri"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "EasternLowland"
ProtoEastern.add_child(name=lang)
date=48300
notes="Eastern dialect -> Proto-Iranian, leaning west"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "SteppeRider"
EasternLowland.add_child(name=lang)
date=42700
notes="Old Persian + Yoruba"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Sorhayan"
SteppeRider.add_child(name=lang)
date=37610
notes="Old Persian + Yoruba var1 + Pashayi"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Darungiatic"
EasternLowland.add_child(name=lang)
date=41300
notes="(Median / Proto-Kurdish + Yoruba), matures in the Tiyaran phase"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

#             Darungiatic -> Dewari (Median + Yoruba var.)
#                         -> SouthernDarungiatic (Zaza-Gorani + Yoruba)
#                         -> Shathradaic (Parthian + Yoruba)
#         41300 - Darungiatic
#             32000 - Darungiatic -> Dewari, Southern Darungiatic, Shathradaic
lang = "Dewari"
Darungiatic.add_child(name=lang)
date=32000
notes="Median + Yoruba var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "SouthernDarungiatic"
Darungiatic.add_child(name=lang)
date=32000
notes="Zaza-Gorani + Yoruba var1"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Shathradaic"
Darungiatic.add_child(name=lang)
date=32000
notes="Parthian + Yoruba"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

#     Proto-Eastern (Eastern dialect)-> Gairian (Proto-Caspian / Proto-Gilaki)
#         Gairian -> Later Gairian (Gilaki)

lang = "Gairian"
EasternLowland.add_child(name=lang)
date=48300
notes="Eastern dialect -> Proto-Caspian + Proto-Gilaki"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LaterGairian"
Gairian.add_child(name=lang)
date=32100
notes="Gilaki"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

#     Proto-Eastern (Southern dialect) -> Zarrakayan (Proto-Iranian, leaning eastern + Vedic Sanskrit)
#         Zarrakayan -> Hemanaic (Proto Southeastern Iranian, Proto-Pashto, + Gandhari)
#                     -> Janangh (Pamiri + Shauraseni),
#                     -> SouthernFarmers (Proto-Pashto + Niya),
#                     -> Shanurvic (Pamiri + Paisaci)
#     Proto-Eastern (Southern dialect) -> JurHudai (Proto-Northeastern Iranian, Proto-Bactrian)
#     39000 - ProtoEastern -> Zarrakayan
#         34500 - Zarrakayan -> RGC/Hemanaic, Janangh, SouthernFarmers, Shanurvaic
#     38800 - ProtoEastern -> JurHudai

lang = "Zarrakayan"
ProtoEastern.add_child(name=lang)
date=39000
notes="Southern dialect -> Proto-Iranian, leaning eastern + Vedic Sanskrit"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "JurHudai"
ProtoEastern.add_child(name=lang)
date=38800
notes="Southern dialect -> Proto-Northeastern Iranian, Proto-Bactrian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Hemanaic"
Zarrakayan.add_child(name=lang)
date=34500
notes="Proto-Southeastern Iranian, Proto-Pashto + Gandhari"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Janangh"
Zarrakayan.add_child(name=lang)
date=34500
notes="Pamiri + Shauraseni"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "SouthernFarmers"
Zarrakayan.add_child(name=lang)
date=34500
notes="Proto-Pashto + Niya"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Shanurvic"
Zarrakayan.add_child(name=lang)
date=34500
notes="Pamiri + Paisaci"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)


# Saxum -> Proto-Northern (Proto-Kati), Proto-Suhairian (Proto-Prasuni) (Nuristani branch) - Suhairians, Wuratans + western Samisians, and Chalk Coast
#     Proto-Suhairian -> Narazic (Prasuni + Vedic Sanskrit)
#         Narazic -> Suhairian (Prasuni-var1 + Sanskrit + Yoruba)
#     Proto-Northern -> North Samisian (Kati)
#     Proto-Northern -> Sakulaic (Waigali)
# 49300 - Saxum -> ProtoSuhairian
#     43900 ProtoSuhairian -> Narazic
#         39400 Narazic -> Suhairian
# 44500 - Saxum -> ProtoNorthern
#     39400 - ProtoNorthern -> North Samisian
#     37600 - ProtoNorthern -> Sakulaic

lang = "ProtoNorthern"
Saxum.add_child(name=lang)
date=44500
notes="Proto-Kati"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "NorthSamisian"
ProtoNorthern.add_child(name=lang)
date=39400
notes="Kati"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Sakulaic"
ProtoNorthern.add_child(name=lang)
date=37600
notes="Waigali"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoSuhairian"
Saxum.add_child(name=lang)
date=49300
notes="Proto-Kati"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Narazaic"
ProtoSuhairian.add_child(name=lang)
date=43900
notes="Prasuni + Vedic Sanskrit"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Suhairian"
Narazaic.add_child(name=lang)
date=39400
notes="Prasuni-var1 + Sanskrit + Yoruba"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

print(Saxum.get_ascii(show_internal=True))
# Out:
#              /LaterThandairian-Akshani
#             |
#      /Wesaxian             /-Eyasolic
#     |       |             |
#     |        \ProtoEyasolian-LowlandRemnants
#     |                     |
#     |                      \-ProtoEastAusteran
#     |
#     |                           /-Shukunaic
#     |            /NorthernHuroman
#     |           |               \-Ashamaic
#     |           |
#     |-ProtoHuromanCentralHuroman-Deshgairi
#     |           |
#     |           |-Marmanaic-LaterMarmanaic
#     |           |
#     |            \-Omanusian
#     |
#     |            /EarlyNorthGhahakan-Uruvandi
#     |           |
#     |           |--EarlyEastGhahakan
#     |           |
#     |           |-EarlyCentralGhahakan-Shestraluki
#     |           |
#     |           |              /SteppeRider-Sorhayan
# -Saxum          |             |
#     |           |             |           /-Dewari
#     |           |             |          |
#     |           |-EasternLowlandDarungiatic-SouthernDarungiatic
#     |           |             |          |
#     |-ProtoEastern            |           \-Shathradaic
#     |           |             |
#     |           |              \Gairian-LaterGairian
#     |           |
#     |           |          /-Hemanaic
#     |           |         |
#     |           |         |--Janangh
#     |           |-Zarrakayan
#     |           |         |--SouthernFarmers
#     |           |         |
#     |           |          \-Shanurvic
#     |           |
#     |            \-JurHudai
#     |
#     |             /-NorthSamisian
#     |-ProtoNorthern
#     |             \-Sakulaic
#     |
#      \ProtoSuhairianNarazaic-Suhairian

# %%
lang = "ProtoDavak"
Jorosh.add_child(name=lang)
date=50700
notes="Tolkein Elvish + PIE"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Davak"
ProtoDavak.add_child(name=lang)
date=46400
notes="Proto-Balto-Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoYedral"
Davak.add_child(name=lang)
date=42500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Yedral"
ProtoYedral.add_child(name=lang)
date=41700
notes="Proto-South Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "VulgarYedral"
Yedral.add_child(name=lang)
date=33700
notes="Slovene"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Iryesi"
Yedral.add_sister(name=lang)
date=41700
notes="Old Church Slavonic / Proto-Southeast Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoHoditic"
Yedral.add_sister(name=lang)
date=41700
notes="Proto-South Slavic + Galatian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Yezerean"
ProtoHoditic.add_child(name=lang)
date=34900
notes="Galatian+Luwian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Dazdavecherian"
ProtoHoditic.add_child(name=lang)
date=34900
notes="Galatian+Hittite"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Lokizdun"
ProtoHoditic.add_child(name=lang)
date=34900
notes="Galatian+Lydian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Voinic"
Davak.add_child(name=lang)
date=41700
notes="Proto-West Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LaterVoinic"
Davak.add_child(name=lang)
date=41700
notes="Old West Slavic + Proto-Germanic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Pisk"
Davak.add_child(name=lang)
date=41700
notes="Proto-Germanic + Proto-Balto-Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Vuzthidic"
Pisk.add_child(name=lang)
date=32200
notes="Proto-East Germanic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Sorfylic"
Pisk.add_child(name=lang)
date=32200
notes="Old Norse"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Angthedic"
Pisk.add_child(name=lang)
date=32200
notes="Proto-West Germanic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Hwistalic"
Pisk.add_child(name=lang)
date=32200
notes="Old High German"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Zvir"
Davak.add_child(name=lang)
date=41700
notes="Proto-Baltic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Zjambese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Baltic + Proto-Caucasian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Skirgan"
Zvir.add_child(name=lang)
date=34000
notes="Galindan"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Girmish"
Zvir.add_child(name=lang)
date=34000
notes="Sudovian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ugnese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Uralic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Kextese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Caucasian+Lithuanian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "VelGabai"
Zvir.add_child(name=lang)
date=34000
notes="Selonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Nikartean"
Davak.add_child(name=lang)
date=36000
notes="Old East Slavic + Gaulish"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

print(ProtoDavak.get_ascii(show_internal=True))
# Out:
#                           /Yedral-VulgarYedral
#                          |
#                          |--Iryesi
#                /ProtoYedral
#               |          |            /-Yezerean
#               |          |           |
#               |           \ProtoHoditic-Dazdavecherian
#               |                      |
#               |                       \-Lokizdun
#               |
#               |--Voinic
#               |
#               |--LaterVoinic
#               |
#               |    /-Vuzthidic
#               |   |
#               |   |--Sorfylic
#               |-Pisk
# -ProtoDavakDavak  |--Angthedic
#               |   |
#               |    \-Hwistalic
#               |
#               |    /-Zjambese
#               |   |
#               |   |--Skirgan
#               |   |
#               |   |--Girmish
#               |-Zvir
#               |   |--Ugnese
#               |   |
#               |   |--Kextese
#               |   |
#               |    \-VelGabai
#               |
#                \-Nikartean

# %%
print(l.get_ascii(show_internal=True))
# Out:
#                                      /-Yfanald
#                                     |
#                                     |                                /Yedral-VulgarYedral
#                                     |                               |
#                                     |                               |--Iryesi
#                                     |                     /ProtoYedral
#                                     |                    |          |            /-Yezerean
#                                     |                    |          |           |
#                                     |                    |           \ProtoHoditic-Dazdavecherian
#                                     |                    |                      |
#                                     |                    |                       \-Lokizdun
#                                     |                    |
#                                     |                    |--Voinic
#                                     |                    |
#                                     |                    |--LaterVoinic
#                                     |                    |
#                                     |                    |    /-Vuzthidic
#                                     |                    |   |
#                                     |                    |   |--Sorfylic
#                                     |                    |-Pisk
#                                     |-JoroshProtoDavakDavak  |--Angthedic
#                                     |                    |   |
#                                     |                    |    \-Hwistalic
#                                     |                    |
#                                     |                    |    /-Zjambese
#                                     |                    |   |
#                                     |                    |   |--Skirgan
#                                     |                    |   |
#                                     |                    |   |--Girmish
#                                     |                    |-Zvir
#                                     |                    |   |--Ugnese
#                                     |                    |   |
#                                     |                    |   |--Kextese
#                                     |                    |   |
#                                     |                    |    \-VelGabai
#                                     |                    |
#                                     |                     \-Nikartean
#                                     |
#                                     |             /LaterThandairian-Akshani
#                                     |            |
#                                     |     /Wesaxian             /-Eyasolic
#                                     |    |       |             |
#                                     |    |        \ProtoEyasolian-LowlandRemnants
#                                     |    |                     |
#    /ProtoInivaticInivaticProtoLeilomic   |                      \-ProtoEastAusteran
#   |                                 |    |
#   |                                 |    |                           /-Shukunaic
#   |                                 |    |            /NorthernHuroman
#   |                                 |    |           |               \-Ashamaic
#   |                                 |    |           |
#   |                                 |    |-ProtoHuromanCentralHuroman-Deshgairi
#   |                                 |    |           |
#   |                                 |    |           |-Marmanaic-LaterMarmanaic
#   |                                 |    |           |
#   |                                 |    |            \-Omanusian
#   |                                 |    |
#   |                                 |    |            /EarlyNorthGhahakan-Uruvandi
#   |                                 |    |           |
#   |                                 |    |           |--EarlyEastGhahakan
#   |                                 |    |           |
#   |                                 |    |           |-EarlyCentralGhahakan-Shestraluki
#   |                                 |    |           |
#   |                                 |    |           |              /SteppeRider-Sorhayan
#   |                                 |-Saxum          |             |
#   |                                 |    |           |             |           /-Dewari
#   |                                 |    |           |             |          |
#   |                                 |    |           |-EasternLowlandDarungiatic-SouthernDarungiatic
#   |                                 |    |           |             |          |
#   |                                 |    |-ProtoEastern            |           \-Shathradaic
#   |                                 |    |           |             |
#   |                                 |    |           |              \Gairian-LaterGairian
# --|                                 |    |           |
#   |                                 |    |           |          /-Hemanaic
#   |                                 |    |           |         |
#   |                                 |    |           |         |--Janangh
#   |                                 |    |           |-Zarrakayan
#   |                                 |    |           |         |--SouthernFarmers
#   |                                 |    |           |         |
#   |                                 |    |           |          \-Shanurvic
#   |                                 |    |           |
#   |                                 |    |            \-JurHudai
#   |                                 |    |
#   |                                 |    |             /-NorthSamisian
#   |                                 |    |-ProtoNorthern
#   |                                 |    |             \-Sakulaic
#   |                                 |    |
#   |                                 |     \ProtoSuhairianNarazaic-Suhairian
#   |                                 |
#   |                                  \EldhProtoAmarthian-Amarthian
#   |
#   |            /-Keleshi
#   |           |
#   |-ProtoKeleshi       /-Ebo
#   |           |       |
#   |            \ProtoEbo-Isikali
#   |                   |
#   |                    \-Yaltalese
#   |
#    \-Emakeel

# %%
mindist = 100000000000000
for node in ProtoLeilomic.iter_descendants("postorder"):
    if node.up.is_root() == False:
        node.dist = ((l&node.name).up.date - node.date)/1000
        if node.dist < mindist and node.dist != 0.0 :
            mindist = node.dist
    else:
        print("No parent: ",node.name)

# %%
ts = TreeStyle()
ts.show_leaf_name = False
ts.layout_fn = mylayout
#ts.rotation=90
ts.scale =  15/mindist
# ts.mode = "c"
# ts.arc_start = -90#45 # 0 degrees = 3 o'clock
# ts.arc_span = 180
l.show(tree_style = ts)

# %%
ts = TreeStyle()
ts.show_leaf_name = True
ts.mode = "c"
ts.arc_start = -90 # 0 degrees = 3 o'clock
ts.arc_span = 360
l.show(tree_style=ts)

# %% [markdown]
# # Cultures

# %%
c = Tree() # Creates an empty tree
#############################
#WAITH TREE
############
#=
cult = "SarnI"
c.add_child(name=cult)
date=500000
notes=""
(c&cult).add_features(date=date,notes=notes)
getvar = "{}=(c&cult)".format(cult)
exec(getvar)
