# %%
from ete3 import Tree, TreeStyle, NodeStyle,faces, TextFace, add_face_to_node

# %%
t = Tree() # Creates an empty tree
#############################
#WAITH TREE
############
#=
culture = "ProtoInivatic"
t.add_child(name=culture)
lang="Proto-Inivatic (Proto - Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#==
culture = "Sarnean"
ProtoInivatic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#==
culture = "Uso"
Sarnean.add_sister(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Akh"
Uso.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Lung"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Luan"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Ceat"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#===
culture = "Rhun"
Sarnean.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#====
culture = "Anariimaic"
Rhun.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

#=====
culture = "Vanhar"
Anariimaic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Erya"
Anariimaic.add_child(name=culture)
lang="Inivatic (Tolkein Elvish)"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(ProtoInivatic.get_ascii(show_internal=True))
# Out:
#                     /-Lung
#                    |
#                    |--Luan
#              /Sarnean
#             |      |--Ceat
#             |      |
# -ProtoInivatic     |              /-Vanhar
#             |       \RhunAnariimaic
#             |                     \-Erya
#             |
#              \Uso-Akh

# %%
#############################
#LOSS'KELVAR AND ORUN TREE
############
culture = "ProtoKeleshi"
t.add_child(name=culture)
lang="Proto-Keleshi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Keleshi"
ProtoKeleshi.add_child(name=culture)
lang="Keleshi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoOrun"
ProtoKeleshi.add_child(name=culture)
lang="Proto-Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Akobean"
ProtoOrun.add_child(name=culture)
lang="Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Isikal"
ProtoOrun.add_child(name=culture)
lang="Isikali"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Kekere"
ProtoOrun.add_child(name=culture)
lang="Yaltalese"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Nlashikir"
Akobean.add_child(name=culture)
lang="Ebo"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(ProtoKeleshi.get_ascii(show_internal=True))
# Out:
#             /-Keleshi
#            |
# -ProtoKeleshi        /Akobean-Nlashikir
#            |        |
#             \ProtoOrun-Isikal
#                     |
#                      \-Kekere

# %%
#############################
#ASTAR CULTURES
############
culture = "Yfanald"
t.add_child(name=culture)
lang="Anariimaic"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Tellin"
Yfanald.add_child(name=culture)
lang="Wesaxian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Eyasolian"
Tellin.add_child(name=culture)
lang="Wesaxian -> Eyasolian by 34200"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Rajanan"
Tellin.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Thandairian"
Tellin.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Suhairian"
Thandairian.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)


culture = "Akshani"
Thandairian.add_child(name=culture)
lang="Later Thandairian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoHuroman"
Yfanald.add_child(name=culture)
lang="Proto-Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "CentralHuroman"
ProtoHuroman.add_child(name=culture)
lang="Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "CoastalHuroman"
ProtoHuroman.add_child(name=culture)
lang="Huroman"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "ProtoEastern"
Yfanald.add_child(name=culture)
lang="ProtoEastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Ghahaka"
ProtoEastern.add_child(name=culture)
lang="Ghahakan"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "NorthSamisian"
ProtoEastern.add_child(name=culture)
lang="dia. Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Sakula"
NorthSamisian.add_child(name=culture)
lang="dia. Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "EastSamisian"
ProtoEastern.add_child(name=culture)
lang="East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Gairiatic"
EastSamisian.add_child(name=culture)
lang="dia. East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Darungian"
EastSamisian.add_child(name=culture)
lang="dia. East Samisian"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "JirElesin"
EastSamisian.add_child(name=culture)
lang="Jir-Elesi"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Vinaltakhan"
ProtoEastern.add_child(name=culture)
lang="Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "JurHudai"
Vinaltakhan.add_child(name=culture)
lang="Proto-Eastern"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Savatumra"
Vinaltakhan.add_child(name=culture)
lang="Savatumran"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

culture = "Zarrakayan"
Savatumra.add_child(name=culture)
lang="Zarrakayan"
date=0
morph=""
notes=""
(t&culture).add_features(lang=lang,date=date,morph=morph,notes=notes)
getvar = "{}=(t&culture)".format(culture)
exec(getvar)

print(Yfanald.get_ascii(show_internal=True))
# Out:
#              /-Eyasolian
#             |
#        /Tellin-Rajanan
#       |     |
#       |     |           /-Suhairian
#       |      \Thandairian
#       |                 \-Akshani
#       |
#       |            /-CentralHuroman
# -YfanaldProtoHuroman
#       |            \-CoastalHuroman
#       |
#       |            /-Ghahaka
#       |           |
#       |           |-NorthSamisian-Sakula
#       |           |
#       |           |            /-Gairiatic
#        \ProtoEastern          |
#                   |-EastSamisian-Darungian
#                   |           |
#                   |            \-JirElesin
#                   |
#                   |           /-JurHudai
#                    \Vinaltakhan
#                               \Savatumra-Zarrakayan

# %%
print(t.get_ascii(show_internal=True))
# Out:
#                        /-Lung
#                       |
#                       |--Luan
#                 /Sarnean
#                |      |--Ceat
#                |      |
#    /ProtoInivatic     |              /-Vanhar
#   |            |       \RhunAnariimaic
#   |            |                     \-Erya
#   |            |
#   |             \Uso-Akh
#   |
#   |            /-Keleshi
#   |           |
#   |-ProtoKeleshi        /Akobean-Nlashikir
#   |           |        |
#   |            \ProtoOrun-Isikal
# --|                    |
#   |                     \-Kekere
#   |
#   |             /-Eyasolian
#   |            |
#   |       /Tellin-Rajanan
#   |      |     |
#   |      |     |           /-Suhairian
#   |      |      \Thandairian
#   |      |                 \-Akshani
#   |      |
#   |      |            /-CentralHuroman
#    \YfanaldProtoHuroman
#          |            \-CoastalHuroman
#          |
#          |            /-Ghahaka
#          |           |
# ...

# %%
ts = TreeStyle()
ts.show_leaf_name = True
ts.scale =  120 # 120 pixels per branch length unit
t.show(tree_style=ts)

# %%
ts = TreeStyle()
ts.show_leaf_name = True
ts.mode = "c"
ts.arc_start = -90 # 0 degrees = 3 o'clock
ts.arc_span = 180
t.show(tree_style=ts)

# %%
# for n in t.traverse():
#     if n.exist == "extinct"
#     nstyle = NodeStyle()
#     nstyle["fgcolor"] = "red"
#     nstyle["size"] = 15
#     n.set_style(nstyle)

# # Let's now modify the aspect of the root node
# t.img_style["size"] = 30
# t.img_style["fgcolor"] = "blue"

# t.show(tree_style=ts)

# %% [markdown]
# # Languages

# %%
def mylayout(node):
    #Add the general start date to each node
    # text faces support multiline. We add a text face
    # with the whole description of each leaf.
#     descFace = faces.TextFace(node.name, fsize=10)
#     descFace.margin_top = 10
#     descFace.margin_bottom = 10
#     descFace.border.margin = 1
    if not node.is_root():
        F = TextFace(node.name+"\n"+str(node.date), tight_text=False)
        add_face_to_node(F, node, column=0, position="branch-right")

    # Note that this faces is added in "aligned" mode
#     faces.add_face_to_node(descFace, node, column=0, aligned=True)

#     # Sets the style of leaf nodes
#     node.img_style["size"] = 5
#     node.img_style["shape"] = "circle"
# #     #If node is an internal node
#     else:
#         # Sets the style of internal nodes
#         node.img_style["size"] = 6
#         node.img_style["shape"] = "circle"
#         node.img_style["fgcolor"] = "#000000"

# %%
# ts = TreeStyle()
# ts.show_leaf_name = False
# def my_layout(node):
#         F = TextFace(node.name, tight_text=True)
#         add_face_to_node(F, node, column=0, position="branch-right")
# ts.layout_fn = my_layout
# t.show(tree_style=ts)

# %%
l = Tree() # Creates an empty tree
#############################
#WAITH TREE
############
#=
lang = "ProtoInivatic"
l.add_child(name=lang)
date=500000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Inivatic"
ProtoInivatic.add_child(name=lang)
date=350000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoLeilomic"
Inivatic.add_child(name=lang)
date=68000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)


lang = "Yfanald"
ProtoLeilomic.add_child(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Jorosh"
Yfanald.add_sister(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoDavak"
Jorosh.add_child(name=lang)
date=50700
notes="Tolkein Elvish + PIE"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Davak"
ProtoDavak.add_child(name=lang)
date=46400
notes="Proto-Balto-Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoYedral"
Davak.add_child(name=lang)
date=42500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Yedral"
ProtoYedral.add_child(name=lang)
date=41700
notes="Proto-South Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "VulgarYedral"
Yedral.add_child(name=lang)
date=33700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Iryesi"
Yedral.add_sister(name=lang)
date=41700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoHoditi"
Yedral.add_sister(name=lang)
date=41700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Hoditi"
ProtoHoditi.add_child(name=lang)
date=34900
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Voinic"
Davak.add_child(name=lang)
date=41700
notes="Proto-West Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Pisk"
Davak.add_child(name=lang)
date=41700
notes="Proto-Germanic + Proto-Balto-Slavic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "post pisk"
Pisk.add_child(name=lang)
date=32200
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Zvir"
Davak.add_child(name=lang)
date=41700
notes="Proto-Baltic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Zjambese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Baltic + Proto-Germanic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Skirgan"
Zvir.add_child(name=lang)
date=34000
notes="Galindan"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Girmish"
Zvir.add_child(name=lang)
date=34000
notes="Sudovian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ugnese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Uralic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Kextese"
Zvir.add_child(name=lang)
date=34000
notes="Proto-Germanic+Lithuanian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "VelGabai"
Zvir.add_child(name=lang)
date=34000
notes="Selonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Nikartean"
Davak.add_child(name=lang)
date=36000
notes="Proto-East Slavic + Gaulish"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Eldh"
Yfanald.add_sister(name=lang)
date=57600
notes="Proto-Celtic"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoAmarthian"
Eldh.add_child(name=lang)
date=47000
notes="Proto-Celtic + Estonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Amarthian"
Eldh.add_child(name=lang)
date=37000
notes="Gaulish + Estonian"
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)


lang = "Saxum"
Yfanald.add_sister(name=lang)
date=57600
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Wesaxian"
Saxum.add_child(name=lang)
date=49700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Eyasolian"
Wesaxian.add_child(name=lang)
date=34200
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "LaterThandairian"
Wesaxian.add_child(name=lang)
date=39000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Akshani"
LaterThandairian.add_child(name=lang)
date=39000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoHuroman"
Saxum.add_child(name=lang)
date=49700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Huroman"
ProtoHuroman.add_child(name=lang)
date=49700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoEastern"
Saxum.add_child(name=lang)
date=49700
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ghahakan"
ProtoEastern.add_child(name=lang)
date=47500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "EastSamisian"
ProtoEastern.add_child(name=lang)
date=48300
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "JirElesi"
EastSamisian.add_child(name=lang)
date=47500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Zarrakayan"
ProtoEastern.add_child(name=lang)
date=47500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "JurHudai"
Zarrakayan.add_sister(name=lang)
date=47500
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoKeleshi"
l.add_child(name=lang)
date=500000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Keleshi"
ProtoKeleshi.add_child(name=lang)
date=350000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "ProtoEbo"
ProtoKeleshi.add_child(name=lang)
date=280000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Ebo"
ProtoEbo.add_child(name=lang)
date=164000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Isikali"
ProtoEbo.add_child(name=lang)
date=160000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

lang = "Yaltalese"
ProtoEbo.add_child(name=lang)
date=160000
notes=""
(l&lang).add_features(date=date,notes=notes)
getvar = "{}=(l&lang)".format(lang)
exec(getvar)

print(l.get_ascii(show_internal=True))
# Out:
#                                      /-Yfanald
#                                     |
#                                     |                                /-Yedral
#                                     |                               |
#                                     |                     /ProtoYedral-Iryesi
#                                     |                    |          |
#                                     |                    |           \-ProtoHoditi
#                                     |                    |
#                                     |                    |--Voinic
#                                     |                    |
#                                     |                    |--Pisk
#                                     |                    |
#                                     |                    |    /-Zjambese
#                                     |                    |   |
# ...

# %%
ts = TreeStyle()
ts.show_leaf_name = False
ts.layout_fn = mylayout
l.show(tree_style = ts)
